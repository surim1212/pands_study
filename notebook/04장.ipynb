# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.load_dataset('tips')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips = sns.load_dataset('tips')

# %%
tips.sample()
# Out:
#     total_bill   tip   sex smoker  day    time  size
# 15       21.58  3.92  Male     No  Sun  Dinner     2

# %%
tips.sex.cat.categories
# Out:
# Index(['Male', 'Female'], dtype='object')

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
plt.figure()

# %%
plt.rc('font',family='D2Coding')
fig = plt.figure()
axes1 = fig.add_subplot(1,1,1)
axes1.hist(data=tips,x='total_bill',bins=5,rwidth=0.8,color='#FFB9B9')
axes1.set_title('히스토그램')
axes1.set_xlabel('Total bill')
axes1.set_ylabel('Frequency')
plt.show()

# %%
plt.rcParams['font.family']
['D2Coding']
# Out:
# ['D2Coding']

# %%
import matplotlib

# %%
matplotlib.matplotlib_fname()
# Out:
# 'C:\\Users\\user\\anaconda3\\Lib\\site-packages\\matplotlib\\mpl-data\\matplotlibrc'

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter('total_bill','tip',data=tips)
plt.show()

# %%
x = [
    tips[tips['sex']=='Female']['tip'],
    tips[tips['sex']=='Male']['tip']
]

# %%
x
# Out:
# [0      1.01
#  4      3.61
#  11     5.00
#  14     3.02
#  16     1.67
#         ...
#  226    2.00
#  229    2.88
#  238    4.67
#  240    2.00
#  243    3.00
#  Name: tip, Length: 87, dtype: float64,
#  Series([], Name: tip, dtype: float64)]

# %%
boxplot = plt.figure()
axes1 = boxplot.add_subplot(1, 1, 1)
axes1.boxplot(
    x=[
        tips[tips['sex'] == 'Female']['tip'],
        tips[tips['sex'] == 'Male']['tip']
    ],
    tick_labels=['Female', 'Male']
)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x28d481c9d60>,
#   <matplotlib.lines.Line2D at 0x28d481ca4b0>,
#   <matplotlib.lines.Line2D at 0x28d480a93d0>,
#   <matplotlib.lines.Line2D at 0x28d480a9700>],
#  'caps': [<matplotlib.lines.Line2D at 0x28d4821a510>,
#   <matplotlib.lines.Line2D at 0x28d48219880>,
#   <matplotlib.lines.Line2D at 0x28d480aa120>,
#   <matplotlib.lines.Line2D at 0x28d480ab410>],
#  'boxes': [<matplotlib.lines.Line2D at 0x28d481c9850>,
#   <matplotlib.lines.Line2D at 0x28d481e9e50>],
#  'medians': [<matplotlib.lines.Line2D at 0x28d4821a0f0>,
#   <matplotlib.lines.Line2D at 0x28d480ab860>],
#  'fliers': [<matplotlib.lines.Line2D at 0x28d481eaed0>,
#   <matplotlib.lines.Line2D at 0x28d480abb60>],
#  'means': []}

# %%
print(matplotlib.__version__)
# Out:
# 3.9.2

# %%
colors = {"Female":"#f1a340","Male":"#998ec3"}
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1, 1, 1)
axes1.scatter(data=tips,
              x='total_bill',
              y='tip',
              s=tips['size']**2*10,
              c=tips['sex'].map(colors),
              alpha=0.5)
plt.show()

# %%
sns.set_context('paper')

# %%
hist,ax = plt.subplots()

sns.histplot(data=tips, x='total_bill', ax=ax,kde=True)
ax.set_title('Total Bill Histogram')
ax.set_xlabel('Total Bill')
plt.show()

# %%
rug, ax = plt.subplots()

sns.rugplot(data=tips, x='total_bill', ax=ax)
sns.histplot(data=tips, x='total_bill', ax=ax)

ax.set_title('Rug Plot and Histogram of Total Bill')

plt.show()

# %%
fig = sns.displot(data=tips, x='total_bill', kde=True, rug=True)

fig.set_axis_labels(x_var='Total Bill', y_var='Count')
fig.figure.suptitle('Distribution of Total Bill')

plt.show()

# %%
count, ax = plt.subplots()
sns.countplot(data=tips, x='day', palette='viridis', ax=ax)

plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4464\3797826168.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=tips, x='day', palette='viridis', ax=ax)

# %%
scatter, ax = plt.subplots()

sns.scatterplot(data=tips, x='total_bill', y='tip', ax=ax)

ax.set_title('Scatter Plot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')

plt.show()

# %%
reg, ax = plt.subplots()
sns.regplot(data=tips, x='total_bill', y='tip', ax=ax)

ax.set_title('Regression Plot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')

plt.show()

# %%
fig = sns.lmplot(data=tips, x='total_bill', y='tip')
print(type(fig))
plt.show()
# Out:
# <class 'seaborn.axisgrid.FacetGrid'>

# %%
joint = sns.jointplot(data=tips, x='total_bill', y='tip')
joint.set_axis_labels(xlabel='Total Bill', ylabel='Tip')

joint.figure.suptitle('Joint Plot of Total Bill and Tip', y=1.03)

plt.show()

# %%
violin, ax = plt.subplots()

sns.violinplot(data=tips, x='time', y='total_bill', ax=ax)

ax.set_title('Violin plot of total bill by time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total Bill')

plt.show()

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
iris = sns.load_dataset('iris')

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [raw]
# pair_grid = sns.PairGrid(iris)
# pair_grid = pair_grid.map_upper(sns.regplot)
